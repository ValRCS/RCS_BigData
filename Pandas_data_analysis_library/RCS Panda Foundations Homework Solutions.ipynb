# %% [markdown]
# # RCS Panda Foundations Homework Solutions

# %% [markdown]
# ###  Find 25 best(IMDB rating) rated black and white movies that grossed at least 20M
# * Sort by Rating first then gross
# * Sort by 'imdb_score' first then 'gross'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
film = pd.read_csv('data/movie.csv') #films or movies would be more accurate but we are lazy...
film.head()

# %%
film.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html
film=film.set_index('movie_title')
film.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# https://chrisalbon.com/python/data_wrangling/pandas_list_unique_values_in_column/
film.color.unique()
# Out:
# array(['Color', nan, 'Black and White'], dtype=object)

# %%
bw = film[film.color == 'Black and White']

# %%
len(bw)
# Out:
# 204

# %%
bw.gross[:5]
# Out:
# movie_title
# Pearl Harbor       198539855.0
# Die Another Day    160201106.0
# The Aviator        102608827.0
# Ali                 58183966.0
# Casino Royale      167007184.0
# Name: gross, dtype: float64

# %%
bw[:5]
# Out:
#                            color    director_name  num_critic_for_reviews  \
# movie_title
# Pearl Harbor     Black and White      Michael Bay                   191.0
# Die Another Day  Black and White     Lee Tamahori                   264.0
# The Aviator      Black and White  Martin Scorsese                   267.0
# Ali              Black and White     Michael Mann                   174.0
# Casino Royale    Black and White  Martin Campbell                   400.0
#
#                  duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Pearl Harbor        184.0                      0.0                   691.0
# Die Another Day     133.0                     93.0                   746.0
# The Aviator         170.0                  17000.0                   827.0
# Ali                 165.0                      0.0                   780.0
# Casino Royale       144.0                    258.0                   834.0
#
# ...

# %%
bst=bw[bw.gross > 20000000]
len(bst)
# Out:
# 54

# %%
bst.head()
# Out:
#                            color    director_name  num_critic_for_reviews  \
# movie_title
# Pearl Harbor     Black and White      Michael Bay                   191.0
# Die Another Day  Black and White     Lee Tamahori                   264.0
# The Aviator      Black and White  Martin Scorsese                   267.0
# Ali              Black and White     Michael Mann                   174.0
# Casino Royale    Black and White  Martin Campbell                   400.0
#
#                  duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Pearl Harbor        184.0                      0.0                   691.0
# Die Another Day     133.0                     93.0                   746.0
# The Aviator         170.0                  17000.0                   827.0
# Ali                 165.0                      0.0                   780.0
# Casino Royale       144.0                    258.0                   834.0
#
# ...

# %%
bst.tail()
# Out:
#                                        color   director_name  \
# movie_title
# Some Like It Hot             Black and White    Billy Wilder
# The Wizard of Oz             Black and White  Victor Fleming
# Young Frankenstein           Black and White      Mel Brooks
# The Best Years of Our Lives  Black and White   William Wyler
# The Blair Witch Project      Black and White   Daniel Myrick
#
#                              num_critic_for_reviews  duration  \
# movie_title
# Some Like It Hot                              181.0     120.0
# The Wizard of Oz                              213.0     102.0
# Young Frankenstein                            129.0     106.0
# The Best Years of Our Lives                    97.0     172.0
# The Blair Witch Project                       360.0      81.0
#
#                              director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Some Like It Hot                                 0.0                   102.0
# ...

# %%
sortedmovies = bst.sort_values(by=['imdb_score','gross']) # so in case of equal imdb_score gross is the tiebreaker
sortedmovies.head()
# Out:
#                                                         color  \
# movie_title
# A Nightmare on Elm Street 5: The Dream Child  Black and White
# Eragon                                        Black and White
# Barbershop 2: Back in Business                Black and White
# The League of Extraordinary Gentlemen         Black and White
# At First Sight                                Black and White
#
#                                                       director_name  \
# movie_title
# A Nightmare on Elm Street 5: The Dream Child        Stephen Hopkins
# Eragon                                             Stefen Fangmeier
# Barbershop 2: Back in Business                Kevin Rodney Sullivan
# The League of Extraordinary Gentlemen            Stephen Norrington
# At First Sight                                        Irwin Winkler
#
#                                               num_critic_for_reviews  \
# movie_title
# ...

# %%
sortedfilms = bst.sort_values(by=['imdb_score','gross'],ascending=False) # so in case of equal imdb_score gross is the tiebreaker
sortedfilms.head(25)
# Out:
#                                        color        director_name  \
# movie_title
# Schindler's List             Black and White     Steven Spielberg
# Forrest Gump                 Black and White      Robert Zemeckis
# The Pianist                  Black and White       Roman Polanski
# Psycho                       Black and White     Alfred Hitchcock
# Memento                      Black and White    Christopher Nolan
# Amélie                       Black and White   Jean-Pierre Jeunet
# Some Like It Hot             Black and White         Billy Wilder
# Sin City                     Black and White         Frank Miller
# Kill Bill: Vol. 1            Black and White    Quentin Tarantino
# The Best Years of Our Lives  Black and White        William Wyler
# The Wizard of Oz             Black and White       Victor Fleming
# Casino Royale                Black and White      Martin Campbell
# Young Frankenstein           Black and White           Mel Brooks
# ...

# %%
cols = list(sortedfilms.columns)
len(cols),cols
# Out:
# (27,
#  ['color',
#   'director_name',
#   'num_critic_for_reviews',
#   'duration',
#   'director_facebook_likes',
#   'actor_3_facebook_likes',
#   'actor_2_name',
#   'actor_1_facebook_likes',
#   'gross',
#   'genres',
#   'actor_1_name',
#   'num_voted_users',
#   'cast_total_facebook_likes',
#   'actor_3_name',
#   'facenumber_in_poster',
#   'plot_keywords',
#   'movie_imdb_link',
#   'num_user_for_reviews',
#   'language',
#   'country',
#   'content_rating',
#   'budget',
#   'title_year',
#   'actor_2_facebook_likes',
#   'imdb_score',
#   'aspect_ratio',
#   'movie_facebook_likes'])

# %%
# list remove https://docs.python.org/3.1/tutorial/datastructures.html
# better https://stackoverflow.com/questions/36268749/remove-multiple-items-from-a-python-list-in-just-one-statement
# could just copy paste a new list using an existing list if list is short enough..

# %%
col2 = ['imdb_score','gross','title_year'] + [el for el in cols if el not in ['imdb_score','gross','title_year']]
len(col2),col2
# Out:
# (27,
#  ['imdb_score',
#   'gross',
#   'title_year',
#   'color',
#   'director_name',
#   'num_critic_for_reviews',
#   'duration',
#   'director_facebook_likes',
#   'actor_3_facebook_likes',
#   'actor_2_name',
#   'actor_1_facebook_likes',
#   'genres',
#   'actor_1_name',
#   'num_voted_users',
#   'cast_total_facebook_likes',
#   'actor_3_name',
#   'facenumber_in_poster',
#   'plot_keywords',
#   'movie_imdb_link',
#   'num_user_for_reviews',
#   'language',
#   'country',
#   'content_rating',
#   'budget',
#   'actor_2_facebook_likes',
#   'aspect_ratio',
#   'movie_facebook_likes'])

# %%
bestbwfilms = sortedfilms[col2]

# %%
bestbwfilms.head(25)
# Out:
#                              imdb_score        gross  title_year  \
# movie_title
# Schindler's List                    8.9   96067179.0      1993.0
# Forrest Gump                        8.8  329691196.0      1994.0
# The Pianist                         8.5   32519322.0      2002.0
# Psycho                              8.5   32000000.0      1960.0
# Memento                             8.5   25530884.0      2000.0
# Amélie                              8.4   33201661.0      2001.0
# Some Like It Hot                    8.3   25000000.0      1959.0
# Sin City                            8.1   74098862.0      2005.0
# Kill Bill: Vol. 1                   8.1   70098138.0      2003.0
# The Best Years of Our Lives         8.1   23650000.0      1946.0
# The Wizard of Oz                    8.1   22202612.0      1939.0
# Casino Royale                       8.0  167007184.0      2006.0
# Young Frankenstein                  8.0   86300000.0      1974.0
# ...

# %%
bestbwfilms.head(25).to_excel('bestbwfilms.xlsx')

# %%
# Can we do this in one line?
# Code Golf time!

# %%
df = pd.read_csv('data/movie.csv',index_col='movie_title')
df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# we want the easy filters first
# sorting is more intensive operation and could take longer on larger data sets
df[df.color == 'Black and White'][df.gross > 20000000].sort_values(by=['imdb_score','gross'],ascending=False)[['imdb_score','gross', 'director_name','title_year']].head(25)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              imdb_score        gross        director_name  \
# movie_title
# Schindler's List                    8.9   96067179.0     Steven Spielberg
# Forrest Gump                        8.8  329691196.0      Robert Zemeckis
# The Pianist                         8.5   32519322.0       Roman Polanski
# Psycho                              8.5   32000000.0     Alfred Hitchcock
# Memento                             8.5   25530884.0    Christopher Nolan
# Amélie                              8.4   33201661.0   Jean-Pierre Jeunet
# Some Like It Hot                    8.3   25000000.0         Billy Wilder
# Sin City                            8.1   74098862.0         Frank Miller
# ...

# %%
df[df.color == 'Black and White'].sort_values(by=['imdb_score','gross'],ascending=False).head(25).to_excel('oneline.xlsx')

# %%
# new in pandas 0.13
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.query.html
from numpy.random import randn

df = pd.DataFrame(randn(10, 2), columns=list('ab'))
print(df)
print(df.query('a > b'))
print(df[df.a > df.b]) # same result as the previous expression
# Out:
#           a         b
# 0 -0.082149 -0.841038
# 1  0.927583 -0.468374
# 2 -1.212442 -0.217629
# 3  0.861874 -0.991745
# 4 -0.806748  0.646282
# 5 -0.599941  0.449484
# 6  0.046532 -0.691262
# 7  0.530087  1.874326
# 8  0.715006 -2.228977
# 9 -0.388916  0.936633
#           a         b
# 0 -0.082149 -0.841038
# 1  0.927583 -0.468374
# 3  0.861874 -0.991745
# 6  0.046532 -0.691262
# 8  0.715006 -2.228977
#           a         b
# 0 -0.082149 -0.841038
# 1  0.927583 -0.468374
# 3  0.861874 -0.991745
# 6  0.046532 -0.691262
# 8  0.715006 -2.228977
