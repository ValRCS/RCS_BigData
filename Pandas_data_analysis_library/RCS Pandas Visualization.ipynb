# %% [markdown]
# ___
# # Pandas Data Visualization
#
# Panda has built-in capabilities for data visualization! It's built-off of matplotlib, but it baked into pandas for easier usage!

# %%
# Official Docs: https://pandas.pydata.org/pandas-docs/stable/visualization.html
# Also materials froms https://github.com/jmportilla

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# Let's create some data

# %%
df1=pd.DataFrame(np.random.randint(low=1, high=10, size=(15, 5)),columns=list('ABCDE')) # notice row size comes first
df1
# Out:
#     A  B  C  D  E
# 0   6  8  7  3  5
# 1   2  4  1  6  7
# 2   8  2  2  7  8
# 3   5  6  8  4  4
# 4   2  6  2  3  9
# 5   5  6  8  9  2
# 6   8  5  8  5  8
# 7   2  3  7  2  6
# 8   7  9  1  1  9
# 9   1  8  4  8  6
# 10  7  3  5  1  9
# 11  5  8  3  6  3
# 12  3  7  6  5  8
# 13  6  8  3  3  6
# 14  7  1  8  2  4

# %%
dates=dates = pd.date_range('20180829', periods=15, freq="W")
dates
# Out:
# DatetimeIndex(['2018-09-02', '2018-09-09', '2018-09-16', '2018-09-23',
#                '2018-09-30', '2018-10-07', '2018-10-14', '2018-10-21',
#                '2018-10-28', '2018-11-04', '2018-11-11', '2018-11-18',
#                '2018-11-25', '2018-12-02', '2018-12-09'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df1.index=dates
df1
# Out:
#             A  B  C  D  E
# 2018-09-02  6  8  7  3  5
# 2018-09-09  2  4  1  6  7
# 2018-09-16  8  2  2  7  8
# 2018-09-23  5  6  8  4  4
# 2018-09-30  2  6  2  3  9
# 2018-10-07  5  6  8  9  2
# 2018-10-14  8  5  8  5  8
# 2018-10-21  2  3  7  2  6
# 2018-10-28  7  9  1  1  9
# 2018-11-04  1  8  4  8  6
# 2018-11-11  7  3  5  1  9
# 2018-11-18  5  8  3  6  3
# 2018-11-25  3  7  6  5  8
# 2018-12-02  6  8  3  3  6
# 2018-12-09  7  1  8  2  4

# %%
df1.columns=["Alice","Bob","Carol","Dave","Edgar"]
df1
# Out:
#             Alice  Bob  Carol  Dave  Edgar
# 2018-09-02      6    8      7     3      5
# 2018-09-09      2    4      1     6      7
# 2018-09-16      8    2      2     7      8
# 2018-09-23      5    6      8     4      4
# 2018-09-30      2    6      2     3      9
# 2018-10-07      5    6      8     9      2
# 2018-10-14      8    5      8     5      8
# 2018-10-21      2    3      7     2      6
# 2018-10-28      7    9      1     1      9
# 2018-11-04      1    8      4     8      6
# 2018-11-11      7    3      5     1      9
# 2018-11-18      5    8      3     6      3
# 2018-11-25      3    7      6     5      8
# 2018-12-02      6    8      3     3      6
# 2018-12-09      7    1      8     2      4

# %%
df1['Alice']
# Out:
# 2018-09-02    6
# 2018-09-09    2
# 2018-09-16    8
# 2018-09-23    5
# 2018-09-30    2
# 2018-10-07    5
# 2018-10-14    8
# 2018-10-21    2
# 2018-10-28    7
# 2018-11-04    1
# 2018-11-11    7
# 2018-11-18    5
# 2018-11-25    3
# 2018-12-02    6
# 2018-12-09    7
# Freq: W-SUN, Name: Alice, dtype: int32

# %%
df1[['Alice','Bob']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x091A19B0>,
# ...
#       dtype=object)

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x091A12D0>,
# ...
#       dtype=object)

# %%
df1.to_excel('grades.xlsx')

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets) you can use to make your plots look a little nicer. These style sheets include plot_bmh,plot_fivethirtyeight,plot_ggplot and more. They basically create a set of style rules that your plots follow. I recommend using them, they make all your plots have the same look and feel more professional. You can even create your own if you want your company's plots to all have the same look (it is a bit tedious to create on though).
#
# Here is how to use them.
#
# **Before plt.style.use() your plots look like this:**

# %%
df1['Alice'].hist()

# %% [markdown]
# Call the style:

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Now your plots look like this:

# %%
df1['Alice'].hist()

# %%
plt.style.use('bmh')
df1['Alice'].hist()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
plt.style.use('bmh')

# %%
df1['Alice'].hist()

# %%
plt.style.use('fivethirtyeight')
df1['Alice'].hist()

# %%
plt.style.use('ggplot') #ggplot style

# %% [markdown]
# Let's stick with the ggplot style and actually show you how to utilize pandas built-in plotting capabilities!

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)
# ___

# %% [markdown]
# Let's start going through them!
#
# ## Area

# %%
df1.plot.area(alpha=0.4) # alpha transparency

# %% [markdown]
# ## Barplots

# %%
df1.head()
# Out:
#             Alice  Bob  Carol  Dave  Edgar
# 2018-09-02      6    8      7     3      5
# 2018-09-09      2    4      1     6      7
# 2018-09-16      8    2      2     7      8
# 2018-09-23      5    6      8     4      4
# 2018-09-30      2    6      2     3      9

# %%
df1.plot.bar()

# %%
df1.plot.bar(stacked=True)

# %% [markdown]
# ## Histograms

# %%
df1['Alice'].plot.hist(bins=5) #notice we changed the number of bins

# %% [markdown]
# ## Line Plots

# %%
df1.plot.line(x=df1.index,y='Bob',figsize=(12,3),lw=1)

# %% [markdown]
# ## Scatter Plots

# %%
df1.plot.scatter(x='Alice',y='Bob')# doesnt make much sense here

# %% [markdown]
# You can use c to color based off another column value
# Use cmap to indicate colormap to use.
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %%
df1.plot.scatter(x='Alice',y='Bob',c='Carol',cmap='coolwarm')

# %% [markdown]
# Or use s to indicate size based off another column. s parameter needs to be an array, not just the name of a column:

# %%
df1.plot.scatter(x='Alice',y='Bob',s=df1['Carol']*200)

# %% [markdown]
# ## BoxPlots

# %%
fig2 = df1.plot.box() # Can also pass a by= argument for groupby

# %%
fig1 = df1.plot.box().get_figure()

# %%
type(fig1)
# Out:
# matplotlib.figure.Figure

# %%
fig1.savefig('Boxplot.pdf')

# %%
df1.plot.pie(y="Alice")

# %%
# https://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas
fig=df1.plot.pie(y="Alice")
plt.legend(loc='center left', bbox_to_anchor=(1.5, 0.5)) # (1.5 is x axis for legend)
plt.show()

# %% [markdown]
# ## Hexagonal Bin Plot
#
# Useful for Bivariate Data, alternative to scatterplot:

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['Alice', 'Bob'])
df.plot.hexbin(x='Alice',y='Bob',gridsize=25,cmap='Oranges')

# %% [markdown]
# ____

# %% [markdown]
# ## Kernel Density Estimation plot (KDE)

# %%
# https://en.wikipedia.org/wiki/Kernel_density_estimation

# %%
df1['Alice'].plot.kde()

# %%
df1.plot.density()

# %% [markdown]
# Hopefully you can see why this method of plotting will be a lot easier to use than full-on matplotlib, it balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib plt. call.
#
# We could do some exercises though now.

# %% [markdown]
# ## Exercise
# * Create a a new dataframe df2 , 20 rows , 4 columns, filled with random integers from 1 to 6,
# * columns named W,X,Y,Z, index is date starting from today and daily
#
# * create a Bar plot for X and Y columns
# * save as Bar.pdf
# * create a Box plot for Y,Z columns
# * save as Box.png
# * create a Line plot for first 3 columns
# * save as Line.jpg
# * save your data as mydata.xlsx
#
# ## Ask me or use google if something is not clear :)

# %%
## lots of extra stuff you can do with plots, like moving legends outside
